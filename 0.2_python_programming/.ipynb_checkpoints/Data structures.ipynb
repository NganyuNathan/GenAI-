# %% [markdown]
# Data Structures: a data sturcture is the way data is stored and organized

# %%
# to store multiple data 
name = ["ngwa", "chi", "berinyuy"]
print(name)
# Out:
# ['ngwa', 'chi', 'berinyuy']

# %%
type(name)
# Out:
# list

# %%
Names = ["sunday", "tuesday","wedesday"]

# %%
Names[0]
# Out:
# 'sunday'

# %%
#to add items to a list,
Names.append("thursday")
Names
# Out:
# ['sunday', 'tuesday', 'wedesday', 'thursday', 'thursday']

# %%
# even_numbers =[]
# nnumber=input("enter number")
# number=int(nnumber)


# if number%2 == 0:
#     even_numbers.append(number)
# else:
#    even_numbers.append(4096)
# print(even_numbers)

# %% [markdown]
# SORTING

# %%
odd_number =[1,3,9,13,57]
sorted_odd_nums = sorted(odd_number)
print(sorted_odd_nums)
# Out:
# [1, 3, 9, 13, 57]

# %%
#to delete from the back we use the pop and we use .remove to delete a specific value
# odd_number.pop()
# odd_number.remove(1)
# odd_number

# %%
number = [1,2,3,4,5,5,6]
number
number.reverse()
number
# Out:
# [6, 5, 5, 4, 3, 2, 1]
