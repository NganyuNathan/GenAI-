# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## Exploring python list methods
#
# -.capitalise, .upper, .lower, .slice, .indexing, . and accessing string elements, . strip, .title, .endswidth, .startwidth

# %%
text="i hate real madrid"
print(text.capitalize())
print(text.upper())
print(text.lower())
print(text.title())
print(text.strip())
# print(text..startWidth())
# Out:
# I hate real madrid
# I HATE REAL MADRID
# i hate real madrid
# I Hate Real Madrid
# i hate real madrid

# %%
remove = text.strip()
print(len(remove))
# Out:
# 18

# %% [markdown]
# indexing and how to get a particular element from a code

# %%
greaatings = "HELLO SEED"
# H-> 0
# E-> 1
# L-> 2
greaatings[3]
greaatings[7]
# Out:
# 'E'

# %% [markdown]
# Slicing

# %%
greating2 = "my goat is messi"
greating2[3:7]
# Out:
# 'goat'

# %%
prompt = input("enter an AI PROMPT")
prompt_split = prompt.split()
check_length = 

print("Original prompt is: " + prompt)
print(len(prompt))
print(len(prompt_split))
print("TO UPPERCASE: " + prompt.upper())
print("TO LOWERCASE: " + prompt.lower())
# Out:
# enter an AI PROMPT hello gen ai
# Original prompt is: hello gen ai
# 12
# 3
# TO UPPERCASE: HELLO GEN AI
# TO LOWERCASE: hello gen ai

# %% [markdown]
# explore the split
