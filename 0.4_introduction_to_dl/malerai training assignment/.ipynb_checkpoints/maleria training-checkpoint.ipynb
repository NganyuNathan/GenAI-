# %%
import json
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import(classification_report, confusion_matrix, roc_auc_score, roc_curve)
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv("malaria_train.csv")
test_df = pd.read_csv("malaria_test.csv")
val_df = pd.read_csv("malaria_val.csv")

# T_train,T_val, = train_test_split(
#     train_df,test_size=0.2, random_state=42,
# )


X_train = train_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_train = train_df['Malaria_Positive'].values.astype(np.float32)

X_val = val_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_val = val_df['Malaria_Positive'].values.astype(np.float32)


X_test = test_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_test = test_df['Malaria_Positive'].values.astype(np.float32)

print(f"Train: {X_train.shape}")
print(f" val: {X_val.shape}")
print(f" Test: {X_test.shape}")


print(f" number of features: {X_train.shape[1]}")
# Out:
# Train: (560, 15)
#  val: (120, 15)
#  Test: (120, 15)
#  number of features: 15

# %%
with open("malaria_train.json") as f:
    data = json.load(f)
df = pd.DataFrame(data)
target = "Malaria_Positive"
feature = [
    col for col in df.columns
    if col != target
]
X = df[feature].values.astype(np.float32)
y = df[target].values.astype(np.float32)

print("Loaded malaria dataset")
print(f"Number of features: {len(feature)}")
print(f"Features: {feature}")
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
# Out:
# Loaded malaria dataset
# Number of features: 15
# Features: ['Age', 'Fever_Temp', 'Chills', 'Headache_Severity', 'Vomiting', 'Diarrhea', 'Muscle_Pain', 'Fatigue_Level', 'Sweating', 'Nausea', 'High_Fever', 'Fever_x_Chills', 'Severe_Headache', 'Symptom_Count', 'Vulnerable_Age']
# X shape: (560, 15)
# y shape: (560,)

# %%
def build_ann(No_features):
    inputs = keras.Input(shape=(No_features,), name="features")

    X= keras.layers.Dense(128, kernel_regularizer = keras.regularizers.l2(1e-4))(inputs)
    X= keras.layers.BatchNormalization()(X)
    X= keras.layers.Activation("relu")(X)
    X= keras.layers.Dropout(0.3)(X)


    X= keras.layers.Dense(64, kernel_regularizer = keras.regularizers.l2(1e-4))(X)
    X= keras.layers.BatchNormalization()(X)
    X= keras.layers.Activation("relu")(X)
    X= keras.layers.Dropout(0.3)(X)

    X= keras.layers.Dense(32)(X)
    X= keras.layers.Activation("relu")(X)
    X= keras.layers.Dropout(0.2)(X)

    outputs = keras.layers.Dense(1, activation='sigmoid', name='prob')(X)
    return keras.Model(inputs, outputs, name="maleriaANN")

# %%
model = build_ann(X_train.shape[1])
model.summary()
# Out:
# Model: "maleriaANN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ features (InputLayer)                │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 128)                 │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_19 (Activation)           │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_20 (Activation)           │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_21 (Activation)           │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ prob (Dense)                         │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,185 (51.50 KB)
#  Trainable params: 12,801 (50.00 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=5e-4),
    loss = 'binary_crossentropy',
    metrics=[
        'accuracy',
        keras.metrics.AUC(name='auc'),
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall'),
    ]
)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=25,
        
        restore_best_weights=True, mode='max', verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=10,
        min_lr=1e-6, mode='max', verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        "best_malaria_model.keras", monitor="val_loss",
        save_best_only = True, mode='max', verbose=0
    ),
]
history = model.fit(
    X_train, y_train,
    epochs = 300, batch_size=32,
    validation_data=(X_val, y_val),
    callbacks = callbacks, verbose=1,
)
print(f"\nEpochs run: {len(history.history['loss'])}")
print(f"best val AUC: {max(history.history['val_loss']):.4f}")
# Out:
# Epoch 1/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.7125 - auc: 0.6992 - loss: 0.6353 - precision: 0.7903 - recall: 0.4206 - val_accuracy: 0.9000 - val_auc: 0.9721 - val_loss: 0.5702 - val_precision: 0.9318 - val_recall: 0.8200 - learning_rate: 5.0000e-04
# Epoch 2/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8571 - auc: 0.9297 - loss: 0.4152 - precision: 0.8696 - recall: 0.7725 - val_accuracy: 0.9583 - val_auc: 0.9960 - val_loss: 0.4310 - val_precision: 0.9091 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 3/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9375 - auc: 0.9824 - loss: 0.2890 - precision: 0.9342 - recall: 0.9142 - val_accuracy: 0.9583 - val_auc: 0.9977 - val_loss: 0.3260 - val_precision: 0.9091 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 4/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9554 - auc: 0.9924 - loss: 0.2177 - precision: 0.9483 - recall: 0.9442 - val_accuracy: 0.9667 - val_auc: 0.9981 - val_loss: 0.2466 - val_precision: 0.9259 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 5/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9589 - auc: 0.9921 - loss: 0.1848 - precision: 0.9526 - recall: 0.9485 - val_accuracy: 0.9750 - val_auc: 0.9980 - val_loss: 0.1923 - val_precision: 0.9434 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 6/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9643 - auc: 0.9931 - loss: 0.1514 - precision: 0.9571 - recall: 0.9571 - val_accuracy: 0.9750 - val_auc: 0.9980 - val_loss: 0.1538 - val_precision: 0.9434 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 7/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9732 - auc: 0.9964 - loss: 0.1213 - precision: 0.9739 - recall: 0.9614 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.1273 - val_precision: 0.9434 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Epoch 8/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9661 - auc: 0.9940 - loss: 0.1221 - precision: 0.9573 - recall: 0.9614 - val_accuracy: 0.9750 - val_auc: 0.9989 - val_loss: 0.1084 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 5.0000e-04
# Epoch 9/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9786 - auc: 0.9964 - loss: 0.1056 - precision: 0.9742 - recall: 0.9742 - val_accuracy: 0.9750 - val_auc: 0.9989 - val_loss: 0.0938 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 5.0000e-04
# Epoch 10/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9804 - auc: 0.9979 - loss: 0.0896 - precision: 0.9744 - recall: 0.9785 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0834 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 5.0000e-04
# Epoch 11/300
# 15/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9729 - auc: 0.9961 - loss: 0.0970 - precision: 0.9691 - recall: 0.9641
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9750 - auc: 0.9967 - loss: 0.0917 - precision: 0.9740 - recall: 0.9657 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0770 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 5.0000e-04
# Epoch 12/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9786 - auc: 0.9955 - loss: 0.0927 - precision: 0.9868 - recall: 0.9614 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0743 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 13/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9786 - auc: 0.9975 - loss: 0.0814 - precision: 0.9702 - recall: 0.9785 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0724 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 14/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9893 - auc: 0.9983 - loss: 0.0708 - precision: 0.9871 - recall: 0.9871 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0703 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 15/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - auc: 0.9982 - loss: 0.0729 - precision: 0.9829 - recall: 0.9871 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0685 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 16/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9857 - auc: 0.9990 - loss: 0.0663 - precision: 0.9787 - recall: 0.9871 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0669 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 17/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9768 - auc: 0.9983 - loss: 0.0735 - precision: 0.9701 - recall: 0.9742 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0653 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 18/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9804 - auc: 0.9991 - loss: 0.0660 - precision: 0.9826 - recall: 0.9700 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0637 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 19/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9857 - auc: 0.9992 - loss: 0.0604 - precision: 0.9828 - recall: 0.9828 - val_accuracy: 0.9833 - val_auc: 0.9989 - val_loss: 0.0628 - val_precision: 0.9800 - val_recall: 0.9800 - learning_rate: 2.5000e-04
# Epoch 20/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9839 - auc: 0.9989 - loss: 0.0629 - precision: 0.9746 - recall: 0.9871 - val_accuracy: 0.9750 - val_auc: 0.9989 - val_loss: 0.0620 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 2.5000e-04
# Epoch 21/300
# 15/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - auc: 0.9982 - loss: 0.0658 - precision: 0.9845 - recall: 0.9744
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9857 - auc: 0.9986 - loss: 0.0603 - precision: 0.9870 - recall: 0.9785 - val_accuracy: 0.9750 - val_auc: 0.9991 - val_loss: 0.0609 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 2.5000e-04
# Epoch 22/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9804 - auc: 0.9983 - loss: 0.0658 - precision: 0.9703 - recall: 0.9828 - val_accuracy: 0.9750 - val_auc: 0.9991 - val_loss: 0.0606 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 23/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9839 - auc: 0.9988 - loss: 0.0630 - precision: 0.9706 - recall: 0.9914 - val_accuracy: 0.9750 - val_auc: 0.9990 - val_loss: 0.0602 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 24/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9839 - auc: 0.9988 - loss: 0.0644 - precision: 0.9786 - recall: 0.9828 - val_accuracy: 0.9750 - val_auc: 0.9990 - val_loss: 0.0596 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 25/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9804 - auc: 0.9980 - loss: 0.0678 - precision: 0.9784 - recall: 0.9742 - val_accuracy: 0.9750 - val_auc: 0.9991 - val_loss: 0.0589 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 26/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9839 - auc: 0.9991 - loss: 0.0567 - precision: 0.9828 - recall: 0.9785 - val_accuracy: 0.9750 - val_auc: 0.9991 - val_loss: 0.0581 - val_precision: 0.9796 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Epochs run: 26
# best val AUC: 0.5702

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].plot(history.history["loss"], label='Train')
axes[0].plot(history.history["val_loss"], label='Validation')
axes[0].set_title("loss")
axes[0].set_xlabel('Epoch')
axes[0].legend()

axes[1].plot(history.history["accuracy"], label='Train')
axes[1].plot(history.history["val_accuracy"], label='Validation')
axes[1].set_title("Accuracy")
axes[1].set_xlabel('Epoch')
axes[1].legend()

# axes[2].scatter(y_test, y_pred, alpha=0.3, s=5, color="steelblue")
axes[2].plot(history.history['auc'],  label='Train')
axes[2].plot(history.history['val_auc'],  label='Validation')
axes[2].set_xlabel('Epoch')
axes[2].set_title('AUC')
axes[2].legend()

plt.suptitle('Training history', fontsize=13)
plt.tight_layout()
plt.savefig('training_history.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
model.load_weights('best_malaria_model.keras')
test_results = model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, test_results):
    print(f"{name:<12}: {value:.4f}")
# Out:
# loss        : 0.5685
# compile_metrics: 0.9417

# %%
y_prob = model.predict(X_test, verbose = 0).flatten()
auc_score = roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize = (5, 5))
plt.plot(fpr, tpr, color='green', label=f'roc curve(AUC = {auc_score:.3f})')
plt.plot([0,1],[0,1], color='blue', linestyle='--', label="Random quess3")
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC Curve')
plt.legend()
plt.tight_layout()
plt.savefig("roc_curve.png", dpi=150, bbox_inches='tight')
plt.show()

print(f'ROC-AUC: {auc_score:.4f}')
# Out:
# ROC-AUC: 0.9689

# %%
y_pred = (y_prob >= 0.5).astype(int)
from sklearn.preprocessing import StandardScaler
import seaborn as sns

print(classification_report(y_test, y_pred, target_names=['No malaria', 'malaria']))
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4.5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
           xticklabels=['No malaria', 'malaria'],
           yticklabels=['No malaria', 'malaria'])
plt.ylabel('Actual')
plt.xlabel('predicted')
plt.title("confusion matrix")
plt.tight_layout()
plt.savefig('confusion_matrix_formalaria.png', dpi=150, bbox_inches = 'tight')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#   No malaria       0.92      0.99      0.95        70
#      malaria       0.98      0.88      0.93        50
#
#     accuracy                           0.94       120
#    macro avg       0.95      0.93      0.94       120
# weighted avg       0.94      0.94      0.94       120

# %%
model.save('malaria_ann.keras')
with open('malaria_inference_kit.pkl', 'wb') as f:
    pickle.dump({
        'feature': feature,
    }, f)
print('saved malaria_ann.keras')
print('saved malaria_inference_kit.pkl')
# Out:
# saved malaria_ann.keras
# saved malaria_inference_kit.pkl

# %%
# def predict_malaria(patient, model, feature, threshold=0.5):
#     patient = patient.copy()
#     row = np.array(
#         [patient[col] for col in feature],
#         dtype=np.float32
#     ).reshape(1, -1)

#     probability = float(
#         model.predict(row, verbose=0)[0][0]
#     )

#     prediction = int(probability >= threshold)

#     result = {
#         "probability": probability,
#         "percentage": probability * 100,
#         "prediction": prediction,
#         "result": (
#             "Malaria"
#             if prediction == 1
#             else "No malaria"
#         )
#     }

#     return result

# %%
# result = predict_malaria(
#     patient,
#     model,
#     feature
# )

# print(f"Probability: {result['percentage']:.2f}%")
# print(f"Result: {result['result']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 2
#       1 result = predict_malaria(
# ----> 2     patient,
#       3     model,
#       4     feature
#       5 )
#       7 print(f"Probability: {result['percentage']:.2f}%")
#       8 print(f"Result: {result['result']}")
#
# NameError: name 'patient' is not defined

# %%
# patient_1 = {
#     'Age':16, 'Fever_Temp':148, 'Chills': 16, 'Headache':2,
#     'Diarrhea': 0, "Muscle_Pain":33.6, 'Fatigue_Level':10, 'Sweating':2, 
#     'Nausea':5, 'High_Fever':148, 'Fever_x_Chills': 16, 'Severe_Headache':16, 'Symptom':1, 'Vulnerable':2,
# }
# print('patient 1 (actual: Diabetes)')
# patient(patient_1, model, feature,)
# Out:
# patient 1 (actual: Diabetes)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 7
#       1 patient_1 = {
#       2     'Age':16, 'Fever_Temp':148, 'Chills': 16, 'Headache':2,
#       3     'Diarrhea': 0, "Muscle_Pain":33.6, 'Fatigue_Level':10, 'Sweating':2,
#       4     'Nausea':5, 'High_Fever':148, 'Fever_x_Chills': 16, 'Severe_Headache':16, 'Symptom':1, 'Vulnerable':2,
#       5 }
#       6 print('patient 1 (actual: Diabetes)')
# ----> 7 patient(patient_1, model, feature,)
#
# NameError: name 'patient' is not defined
